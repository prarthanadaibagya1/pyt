# %%
class employee:#baseclass
    def __init__(self, emp_id, name, salary):
        self.__emp_id= emp_id
        self.__name=name
        self.__salary=salary
#getter
    def get_emp_id(self):
        return self.__emp_id
    def get_name(self):
        return self.__name
    def get_salary(self):
        return self.__salary
#setter
    def set_emp_id(self, emp_id):
        self.__emp_id=emp_id
    def set_name(self, name):
        self.__name=name
    def set_salary(self, salary):
        self.__salary=salary
#subclass
class professor(employee):
    def __init__(self,emp_id , name , salary, subject):
        super().__init__(emp_id, name, salary)
        self.subject = subject
    def display(self):
        print("Employee id:", self.get_emp_id())
        print("Name:", self.get_name())
        print("Salary:", self.get_salary())
        print("Subject:", self.subject)

prof=professor("KIC080BCT028","Er. Prarthana Daibagya",9999999999999999999,"Computer Engineering")
prof.display()
# Out:
# Employee id: KIC080BCT028
# Name: Er. Prarthana Daibagya
# Salary: 9999999999999999999
# Subject: Computer Engineering
